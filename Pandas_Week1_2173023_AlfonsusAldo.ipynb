# %%
import pandas as pd
import numpy as np 

print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.4
# 1.20.3

# %%
n_rows = 5
n_cols = 5
cols = tuple ('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  8  2  4  1  4
# 1  1  4  6  4  4
# 2  9  9  7  6  4
# 3  1  9  9  1  8
# 4  7  3  4  8  4

# %%
tuple ('ABCDE')
# Out:
# ('A', 'B', 'C', 'D', 'E')

# %%
df.add_prefix('kolom_')
# Out:
#    kolom_A  kolom_B  kolom_C  kolom_D  kolom_E
# 0        8        2        4        1        4
# 1        1        4        6        4        4
# 2        9        9        7        6        4
# 3        1        9        9        1        8
# 4        7        3        4        8        4

# %%
df.add_suffix('_field')
# Out:
#    A_field  B_field  C_field  D_field  E_field
# 0        8        2        4        1        4
# 1        1        4        6        4        4
# 2        9        9        7        6        4
# 3        1        9        9        1        8
# 4        7        3        4        8        4

# %%
n_rows = 10
n_cols = 5
cols = tuple ('ABCDE')

df = pd.DataFrame(np.random.randint(1, 5, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  2  4  3  4  2
# 1  3  2  1  1  4
# 2  1  1  3  1  4
# 3  4  3  4  1  1
# 4  3  2  2  4  4
# 5  1  4  4  1  2
# 6  2  4  3  4  1
# 7  2  3  1  1  3
# 8  2  4  1  2  1
# 9  3  4  1  1  1

# %%
df[(df['A']==1) | (df['A']==3)]
# Out:
#    A  B  C  D  E
# 1  3  2  1  1  4
# 2  1  1  3  1  4
# 4  3  2  2  4  4
# 5  1  4  4  1  2
# 9  3  4  1  1  1

# %%
df[df['A'].isin([1, 3])]
# Out:
#    A  B  C  D  E
# 1  3  2  1  1  4
# 2  1  1  3  1  4
# 4  3  2  2  4  4
# 5  1  4  4  1  2
# 9  3  4  1  1  1

# %%
df[~df['A'].isin([1, 3])]
# Out:
#    A  B  C  D  E
# 0  2  4  3  4  2
# 3  4  3  4  1  1
# 6  2  4  3  4  1
# 7  2  3  1  1  3
# 8  2  4  1  2  1

# %%
import pandas as pd
data = {'col1':['1','2','3','teks'],
       'col2':['1','2','3','4']}
df = pd.DataFrame(data)
df
# Out:
#    col1 col2
# 0     1    1
# 1     2    2
# 2     3    3
# 3  teks    4

# %%
df.dtypes
# Out:
# col1    object
# col2    object
# dtype: object

# %%
df_x = df.astype({'col2':'int'})
df_x
# Out:
#    col1  col2
# 0     1     1
# 1     2     2
# 2     3     3
# 3  teks     4

# %%
df_x.dtypes
# Out:
# col1    object
# col2     int32
# dtype: object

# %%
df.apply(pd.to_numeric, errors='coerce')
# Out:
#    col1  col2
# 0   1.0     1
# 1   2.0     2
# 2   3.0     3
# 3   NaN     4

# %%
import numpy as np
import pandas as pd
n_rows = 5
n_cols = 2
cols = ['bil_pecahan','bil_bulat']
df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)),
                 columns=cols)
df['bil_pecahan'] = df['bil_pecahan'].astype('float')
df.index = pd.util.testing.makeDateIndex(n_rows, freq='H')
df = df.reset_index()

df['teks']=list('ABCDE')

df
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\util\__init__.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#                 index  bil_pecahan  bil_bulat teks
# 0 2000-01-01 00:00:00         11.0          7    A
# 1 2000-01-01 01:00:00         16.0         16    B
# 2 2000-01-01 02:00:00         10.0          8    C
# 3 2000-01-01 03:00:00          3.0         13    D
# 4 2000-01-01 04:00:00         10.0         16    E

# %%
df.dtypes
# Out:
# index          datetime64[ns]
# bil_pecahan           float64
# bil_bulat               int32
# teks                   object
# dtype: object

# %%
df.select_dtypes(include='number')
# Out:
#    bil_pecahan  bil_bulat
# 0         11.0          7
# 1         16.0         16
# 2         10.0          8
# 3          3.0         13
# 4         10.0         16

# %%
df.select_dtypes(include='float')
# Out:
#    bil_pecahan
# 0         11.0
# 1         16.0
# 2         10.0
# 3          3.0
# 4         10.0

# %%
df.select_dtypes(include='int')
# Out:
#    bil_bulat
# 0          7
# 1         16
# 2          8
# 3         13
# 4         16

# %%
df.select_dtypes(include='object')
# Out:
#   teks
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E

# %%
df.select_dtypes(include='datetime')
# Out:
#                 index
# 0 2000-01-01 00:00:00
# 1 2000-01-01 01:00:00
# 2 2000-01-01 02:00:00
# 3 2000-01-01 03:00:00
# 4 2000-01-01 04:00:00

# %%
df.select_dtypes(include=['number','object'])
# Out:
#    bil_pecahan  bil_bulat teks
# 0         11.0          7    A
# 1         16.0         16    B
# 2         10.0          8    C
# 3          3.0         13    D
# 4         10.0         16    E
